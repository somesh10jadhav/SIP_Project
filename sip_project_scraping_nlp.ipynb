# %%
#Installing google-play-scraper
! pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.2-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.2

# %%
from google_play_scraper import Sort, reviews_all
import pandas as pd
import numpy as np

# %% [markdown]
# <h1> Scraping Reviews </h1>
#     <p> It is

# %%
#It is taking too much time to scrape all 1.8 Million Reviews
#So 


#Importing 1 star reviews 
result = reviews_all(
    'com.byjus.thelearningapp',
    sleep_milliseconds=0.010, # defaults to 0
    lang='en', # defaults to 'en'
    country='in', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with= 1 # defaults to None(means all score)
)

result = pd.DataFrame(result)

byjus_ps = pd.DataFrame()
byjus_ps['reviews']=result['content']
byjus_ps['score']= result['score']

# %%
#Saving 1 star reviews to csv
result.to_csv('/Users/Jadhav/Desktop/SIP Project/df1.csv')

# %%
result = reviews_all(
    'com.byjus.thelearningapp',
    sleep_milliseconds=0.010, # defaults to 0
    lang='en', # defaults to 'en'
    country='in', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with= 2 # defaults to None(means all score)
)

result = pd.DataFrame(result)

byjus_ps = pd.DataFrame()
byjus_ps['reviews']=result['content']
byjus_ps['score']= result['score']

# %%
result.to_csv('/Users/Jadhav/Desktop/SIP Project/df2.csv')

# %%
result = reviews_all(
    'com.byjus.thelearningapp',
    sleep_milliseconds=0.010, # defaults to 0
    lang='en', # defaults to 'en'
    country='in', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with= 3 # defaults to None(means all score)
)

result = pd.DataFrame(result)

byjus_ps = pd.DataFrame()
byjus_ps['reviews']=result['content']
byjus_ps['score']= result['score']

# %%
result.to_csv('/Users/Jadhav/Desktop/SIP Project/df3.csv')

# %%
result = reviews_all(
    'com.byjus.thelearningapp',
    sleep_milliseconds=0.010, # defaults to 0
    lang='en', # defaults to 'en'
    country='in', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with= 4 # defaults to None(means all score)
)

result = pd.DataFrame(result)

byjus_ps = pd.DataFrame()
byjus_ps['reviews']=result['content']
byjus_ps['score']= result['score']

# %%
result.to_csv('/Users/Jadhav/Desktop/SIP Project/df4.csv')

# %%
result = reviews_all(
    'com.byjus.thelearningapp',
    sleep_milliseconds=0.010, # defaults to 0
    lang='en', # defaults to 'en'
    country='in', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with= 5 # defaults to None(means all score)
)

result = pd.DataFrame(result)

byjus_ps = pd.DataFrame()
byjus_ps['reviews']=result['content']
byjus_ps['score']= result['score']

# %%
result.to_csv('/Users/Jadhav/Desktop/SIP Project/df5.csv')

# %%
result
# Out:
#                                    reviewId              userName  \
# 0      472b3be7-bd4f-43bc-b615-46d048c15e01          Tanya Pathak
# 1      7fd8bcf0-296b-4db5-84dd-2ef67e65f242     Soumyadeep Podder
# 2      adcd1cb8-1ff4-4e34-b1a7-0ff1923cf733  ASHUTOSH KUMAR SINGH
# 3      90a9ad95-b225-4321-9e30-97c52577f764          Disha Sharma
# 4      bfec2bc9-b97a-44a0-9530-245fe2673857         A Google user
# ...                                     ...                   ...
# 54248  0a16f0d6-be84-4645-8363-43d39ee55573         A Google user
# 54249  50c72c22-b2d7-4d45-a4fc-758dbc6767a6         A Google user
# 54250  889d23c2-a861-4ee5-98d7-7ac43a6201c8         A Google user
# 54251  440f2a62-09b4-42d1-8a71-afdf3b19d169         A Google user
# 54252  db7b668c-ca0d-47e3-8f00-17dd69b8ab12         A Google user
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/AD5-W...
# 1      https://play-lh.googleusercontent.com/a-/AD5-W...
# 2      https://play-lh.googleusercontent.com/a-/AD5-W...
# 3      https://play-lh.googleusercontent.com/a-/AD5-W...
# 4      https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                  ...
# 54248  https://play-lh.googleusercontent.com/EGemoI2N...
# 54249  https://play-lh.googleusercontent.com/EGemoI2N...
# 54250  https://play-lh.googleusercontent.com/EGemoI2N...
# 54251  https://play-lh.googleusercontent.com/EGemoI2N...
# 54252  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                  content  score  \
# 0      The explanation is very nice through animation...      1
# 1      Third class app.The only problem is that I get...      1
# 2      Third class app. The only problem is that get ...      1
# 3      The new update is causing lot of problems in r...      1
# 4      I am largely dissapointed by the quality of vi...      1
# ...                                                  ...    ...
# 54248                                               None      1
# 54249                                               None      1
# 54250                                               None      1
# 54251                                               None      1
# 54252                                               None      1
#
#        thumbsUpCount reviewCreatedVersion                  at  \
# 0                 39        10.13.0.15142 2022-12-11 11:22:32
# 1               4095         10.9.2.14517 2022-10-06 20:53:10
# 2                329           7.5.1.9945 2022-11-19 19:35:14
# 3               6934         10.4.0.13552 2022-06-26 17:39:08
# 4                587           5.6.0.7484 2020-04-03 20:32:43
# ...              ...                  ...                 ...
# 54248              0                 None 2016-04-12 16:44:50
# 54249              0                 None 2017-03-08 19:48:39
# 54250              0                 None 2015-08-19 19:11:20
# 54251              0                 None 2017-05-30 16:41:44
# 54252              0                 None 2015-09-02 13:30:28
#
#                                             replyContent           repliedAt
# 0                                                   None                 NaT
# 1      We regret that our team reached out to you mul... 2022-10-07 15:00:55
# 2      \n\nWe regret that our team reached out to you... 2022-11-22 11:41:26
# 3      Apologies for the inconvenience. Please drop u... 2022-06-28 14:41:02
# 4      Thank you for your feedback. We recommend rein... 2020-04-06 22:57:32
# ...                                                  ...                 ...
# 54248                                               None                 NaT
# 54249                                               None                 NaT
# 54250                                               None                 NaT
# 54251                                               None                 NaT
# 54252                                               None                 NaT
#
# [54253 rows x 10 columns]
